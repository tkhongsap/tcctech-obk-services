# %%
from sentence_transformers import SentenceTransformer
from datetime import datetime
from typing import Optional
import logging
import redis
import pickle
import hashlib
import time
import pandas as pd

logger = logging.getLogger(__name__)

# %%
model = SentenceTransformer("BAAI/bge-m3")

# %%
hachiken_cases = [
    "hachiken ramen",
    "hachikenramen",
    "hachiken  ramen",
    "hachlken ramen",
    "hachikn ramen",
    "hachiken ramem",
    "hachikeen ramen",
    "hatchiken ramen",
    "hchiken ramen",
    "hachiken rame",
    "achiken ramen",
    "hachike",
    "ken ramen",
    "hachike ramen",
    "ramen hachiken",
    "hachiram kenmen",
    "ramenhachiken",
    "hachiramenken",
    "haclken ramen",
    "h4chiken ramen",
    "hachiken rarnen",
    "hacnken ramen",
    "hachikem rameu",
    "  hachiken ramen  ",
    "hachiken   ramen",
    "hachiken\nramen",
    "hachiken\t ramen",
    "h a c h i k e n   r a m e n",
    "hachiken ramen noodles",
    "best hachiken ramen",
    "hachikenramen!!",
    "order hachiken ramen now",
    "hachiken ramen shop",
    "hachiken_ ramen",
    "hachiken ramen123",
    "ha c h ik en  rarnen!!!",
    "haclkenramen now",
    "ramen hachiken noodl",
    "hchikn r4men",
    "hatchikem  rame",
    "hachikenramn"
]

starbucks_cases = [
    "starbucks",
    "star bucks",
    "Starbucks",
    "starbuvks",
    "strabucks",
    "starbicks",
    "stqrbucks",
    "starrbucks",
    "starbuck",
    "starbuc",
    "bucksstar",
    "bucks star",
    "st4rbucks",
    "staЯbucks",
    "starnuсks",
    "starbucķs",
    "stɑrbucks",
    "  starbucks  ",
    "star   bucks",
    "star\nbucks",
    "s t a r b u c k s",
    "order starbucks now",
    "best starbucks coffee",
    "st4r buks!!",
    "order staЯbucķs now"
]

pizza_cases = [
    "พิซซ่าคอมปะนี",
    "พิซซ่า คอมปะนี",
    "พิซซ่าคอมปะนีิ",
    "พิซซ่าคอมปะนร",
    "พีซซ่าคอมปะนี",
    "พิซซ่าคอม",
    "คอมปะนี",
    "พิซซ่า",
    "คอมปะนีพิซซ่า",
    "คอมปะนี พิซซ่า",
    "พิซซ่าคอมปะนl",
    "พิซซ่าคอมปะนีิิ",
    "พิซซ่า   คอมปะนี",
    "พิซซ่า\nคอมปะนี",
    "พิซซ่าคอมปะนีเดลิเวอรี่",
    "ร้านพิซซ่าคอมปะนี",
    "พิซซ่า คอม ปะนl!!",
    "พิ ซ ซ่า ค อ ม ปะ นี!!!"
]

iberry_cases = [
    "บริษัท iberry จำกัด มหาชน",
    "บริษัท iberry จำกัดมหาชน",
    "บริษัท iberry จำกัด  มหาชน",
    "บริษท iberry จำกัด มหาชน",
    "บรษัท ibery จำกัด มหาชน",
    "บริษัท ibery จำกัด มหานชน",
    "บริษัท iberry",
    "iberry จำกัด",
    "บริษัท iber",
    "iberry มหาชน",
    "iberry บริษัท จำกัด มหาชน",
    "จำกัด บริษัท iberry มหาชน",
    "บริษัn iberry จำกัด มหาชน",
    "บริษํท iberry จํากัด มหาชน",
    "บ ริ ษั ท iberry จำ กั ด ม ห า ช น",
    "บริษัท\niberry\tจำกัด   มหาชน",
    "บริษัท iberry จำกัด มหาชน ประเทศไทย",
    "iberry จำกัด มหาชน group",
    "iberry จำกัดมหาชน!!",
    "บริษัท iberry จำกัด มหาชน 2025",
    "บริษํท ibery จํากัด มหานชน",
    "บ ริ ษั ท ibery จำกัดมห า ชน",
    "บริษัท ibery มหาชน จำกัด"
]

# %%
hachiken_case = "hachiken ramen"
starbucks_case = 'starbucks'
pizza_case = 'พิซซ่าคอมปะนี'
iberry_case = 'บริษัท iberry จำกัด มหาชน'

# Compute embeddings for both lists
hachiken_embedded = model.encode(hachiken_cases)
hachiken_true_embedded = model.encode(hachiken_case)

starbucks_embedded = model.encode(starbucks_cases)
starbucks_true_embedded = model.encode(starbucks_case)

pizza_embedded = model.encode(pizza_cases)
pizza_true_embedded = model.encode(pizza_case)

iberry_embedded = model.encode(iberry_cases)
iberry_true_embedded = model.encode(iberry_case)

# %%
model_scores = []
for i in range(len(hachiken_embedded)):
    start_time = time.time()
    score = model.similarity(hachiken_embedded[i], hachiken_true_embedded)
    end_time = time.time()
    elapsed = end_time - start_time
    model_scores.append({'test_case': hachiken_cases[i], 'score': score.item()*100, 'time': elapsed})

# %%
for i in range(len(pizza_embedded)):
    start_time = time.time()
    score = model.similarity(pizza_embedded[i], pizza_true_embedded)
    end_time = time.time()
    elapsed = end_time - start_time
    model_scores.append({'test_case': pizza_cases[i], 'score': score.item()*100, 'time': elapsed})

# %%
for i in range(len(iberry_embedded)):
    start_time = time.time()
    score = model.similarity(iberry_embedded[i], iberry_true_embedded)
    end_time = time.time()
    elapsed = end_time - start_time
    model_scores.append({'test_case': iberry_cases[i], 'score': score.item()*100, 'time': elapsed})

# %%
for i in range(len(starbucks_embedded)):
    start_time = time.time()
    score = model.similarity(starbucks_embedded[i], starbucks_true_embedded)
    end_time = time.time()
    elapsed = end_time - start_time
    model_scores.append({'test_case': starbucks_cases[i], 'score': score.item()*100, 'time': elapsed})

# %%
model_scores
# Out:
# [{'test_case': 'hachiken ramen',
#   'score': 99.99999403953552,
#   'time': 0.0005662441253662109},
#  {'test_case': 'hachikenramen',
#   'score': 78.66547703742981,
#   'time': 9.775161743164062e-05},
#  {'test_case': 'hachiken  ramen',
#   'score': 99.99999403953552,
#   'time': 7.343292236328125e-05},
#  {'test_case': 'hachlken ramen',
#   'score': 83.20984244346619,
#   'time': 6.341934204101562e-05},
#  {'test_case': 'hachikn ramen',
#   'score': 92.82689094543457,
#   'time': 6.103515625e-05},
#  {'test_case': 'hachiken ramem',
#   'score': 84.12150740623474,
#   'time': 7.843971252441406e-05},
#  {'test_case': 'hachikeen ramen',
#   'score': 96.05879783630371,
#   'time': 7.152557373046875e-05},
#  {'test_case': 'hatchiken ramen',
#   'score': 93.18318367004395,
#   'time': 7.128715515136719e-05},
#  {'test_case': 'hchiken ramen',
#   'score': 90.67526459693909,
#   'time': 6.246566772460938e-05},
#  {'test_case': 'hachiken rame',
#   'score': 85.4762852191925,
#   'time': 9.036064147949219e-05},
#  {'test_case': 'achiken ramen',
#   'score': 85.92084646224976,
#   'time': 0.00010275840759277344},
#  {'test_case': 'hachike',
#   'score': 71.11637592315674,
#   'time': 0.00010418891906738281},
#  {'test_case': 'ken ramen',
#   'score': 65.5483603477478,
#   'time': 0.00012493133544921875},
#  {'test_case': 'hachike ramen',
#   'score': 91.93851947784424,
#   'time': 7.414817810058594e-05},
#  {'test_case': 'ramen hachiken',
#   'score': 98.04198741912842,
#   'time': 6.222724914550781e-05},
#  {'test_case': 'hachiram kenmen',
#   'score': 59.62308049201965,
#   'time': 7.43865966796875e-05},
#  {'test_case': 'ramenhachiken',
#   'score': 77.8028130531311,
#   'time': 6.246566772460938e-05},
#  {'test_case': 'hachiramenken',
#   'score': 74.54254627227783,
#   'time': 6.246566772460938e-05},
#  {'test_case': 'haclken ramen',
#   'score': 82.06489086151123,
#   'time': 6.031990051269531e-05},
#  {'test_case': 'h4chiken ramen',
#   'score': 79.78838086128235,
#   'time': 6.127357482910156e-05},
#  {'test_case': 'hachiken rarnen',
#   'score': 74.36972856521606,
#   'time': 6.008148193359375e-05},
#  {'test_case': 'hacnken ramen',
#   'score': 83.7212085723877,
#   'time': 6.031990051269531e-05},
#  {'test_case': 'hachikem rameu',
#   'score': 74.41629767417908,
#   'time': 6.175041198730469e-05},
#  {'test_case': '  hachiken ramen  ',
#   'score': 99.99999403953552,
#   'time': 6.079673767089844e-05},
#  {'test_case': 'hachiken   ramen',
#   'score': 99.99999403953552,
#   'time': 6.318092346191406e-05},
#  {'test_case': 'hachiken\nramen',
#   'score': 99.99999403953552,
#   'time': 6.031990051269531e-05},
#  {'test_case': 'hachiken\t ramen',
#   'score': 99.99999403953552,
#   'time': 6.031990051269531e-05},
#  {'test_case': 'h a c h i k e n   r a m e n',
#   'score': 48.61924946308136,
#   'time': 5.91278076171875e-05},
#  {'test_case': 'hachiken ramen noodles',
#   'score': 89.41177725791931,
#   'time': 5.793571472167969e-05},
#  {'test_case': 'best hachiken ramen',
#   'score': 89.11675214767456,
#   'time': 5.936622619628906e-05},
#  {'test_case': 'hachikenramen!!',
#   'score': 66.1044716835022,
#   'time': 5.984306335449219e-05},
#  {'test_case': 'order hachiken ramen now',
#   'score': 84.41253304481506,
#   'time': 6.580352783203125e-05},
#  {'test_case': 'hachiken ramen shop',
#   'score': 90.50801396369934,
#   'time': 6.103515625e-05},
#  {'test_case': 'hachiken_ ramen',
#   'score': 88.67736458778381,
#   'time': 6.008148193359375e-05},
#  {'test_case': 'hachiken ramen123',
#   'score': 79.03103828430176,
#   'time': 6.4849853515625e-05},
#  {'test_case': 'ha c h ik en  rarnen!!!',
#   'score': 46.58140242099762,
#   'time': 6.103515625e-05},
#  {'test_case': 'haclkenramen now',
#   'score': 58.02021622657776,
#   'time': 5.984306335449219e-05},
#  {'test_case': 'ramen hachiken noodl',
#   'score': 89.14951682090759,
#   'time': 5.936622619628906e-05},
#  {'test_case': 'hchikn r4men',
#   'score': 57.24566578865051,
#   'time': 5.984306335449219e-05},
#  {'test_case': 'hatchikem  rame',
#   'score': 76.08003616333008,
#   'time': 5.936622619628906e-05},
#  {'test_case': 'hachikenramn',
#   'score': 76.99586153030396,
#   'time': 5.888938903808594e-05},
#  {'test_case': 'พิซซ่าคอมปะนี',
#   'score': 100.0,
#   'time': 0.00045418739318847656},
#  {'test_case': 'พิซซ่า คอมปะนี',
#   'score': 99.0826964378357,
#   'time': 0.0001163482666015625},
#  {'test_case': 'พิซซ่าคอมปะนีิ',
#   'score': 97.89350032806396,
#   'time': 8.225440979003906e-05},
#  {'test_case': 'พิซซ่าคอมปะนร',
#   'score': 95.49151062965393,
#   'time': 7.724761962890625e-05},
#  {'test_case': 'พีซซ่าคอมปะนี',
#   'score': 93.77544522285461,
#   'time': 7.653236389160156e-05},
#  {'test_case': 'พิซซ่าคอม',
#   'score': 79.26718592643738,
#   'time': 8.988380432128906e-05},
#  {'test_case': 'คอมปะนี',
#   'score': 67.32849478721619,
#   'time': 7.915496826171875e-05},
#  {'test_case': 'พิซซ่า',
#   'score': 82.64214396476746,
#   'time': 7.557868957519531e-05},
#  {'test_case': 'คอมปะนีพิซซ่า',
#   'score': 96.36714458465576,
#   'time': 7.510185241699219e-05},
#  {'test_case': 'คอมปะนี พิซซ่า',
#   'score': 97.27933406829834,
#   'time': 7.534027099609375e-05},
#  {'test_case': 'พิซซ่าคอมปะนl',
#   'score': 90.7662570476532,
#   'time': 7.43865966796875e-05},
#  {'test_case': 'พิซซ่าคอมปะนีิิ',
#   'score': 96.61399126052856,
#   'time': 7.677078247070312e-05},
#  {'test_case': 'พิซซ่า   คอมปะนี',
#   'score': 99.0826964378357,
#   'time': 7.534027099609375e-05},
#  {'test_case': 'พิซซ่า\nคอมปะนี',
#   'score': 99.0826964378357,
#   'time': 7.414817810058594e-05},
#  {'test_case': 'พิซซ่าคอมปะนีเดลิเวอรี่',
#   'score': 89.64006304740906,
#   'time': 7.486343383789062e-05},
#  {'test_case': 'ร้านพิซซ่าคอมปะนี',
#   'score': 94.85944509506226,
#   'time': 7.653236389160156e-05},
#  {'test_case': 'พิซซ่า คอม ปะนl!!',
#   'score': 67.50330328941345,
#   'time': 7.653236389160156e-05},
#  {'test_case': 'พิ ซ ซ่า ค อ ม ปะ นี!!!',
#   'score': 51.44146680831909,
#   'time': 7.677078247070312e-05},
#  {'test_case': 'บริษัท iberry จำกัด มหาชน',
#   'score': 100.0,
#   'time': 0.0002880096435546875},
#  {'test_case': 'บริษัท iberry จำกัดมหาชน',
#   'score': 98.67056012153625,
#   'time': 7.700920104980469e-05},
#  {'test_case': 'บริษัท iberry จำกัด  มหาชน',
#   'score': 100.0,
#   'time': 0.00010275840759277344},
#  {'test_case': 'บริษท iberry จำกัด มหาชน',
#   'score': 97.04652428627014,
#   'time': 9.560585021972656e-05},
#  {'test_case': 'บรษัท ibery จำกัด มหาชน',
#   'score': 77.81856060028076,
#   'time': 8.273124694824219e-05},
#  {'test_case': 'บริษัท ibery จำกัด มหานชน',
#   'score': 63.937002420425415,
#   'time': 7.081031799316406e-05},
#  {'test_case': 'บริษัท iberry',
#   'score': 91.0650372505188,
#   'time': 8.034706115722656e-05},
#  {'test_case': 'iberry จำกัด',
#   'score': 94.16290521621704,
#   'time': 7.176399230957031e-05},
#  {'test_case': 'บริษัท iber',
#   'score': 63.674139976501465,
#   'time': 6.723403930664062e-05},
#  {'test_case': 'iberry มหาชน',
#   'score': 92.69120693206787,
#   'time': 6.103515625e-05},
#  {'test_case': 'iberry บริษัท จำกัด มหาชน',
#   'score': 98.09216260910034,
#   'time': 7.176399230957031e-05},
#  {'test_case': 'จำกัด บริษัท iberry มหาชน',
#   'score': 93.83061528205872,
#   'time': 6.270408630371094e-05},
#  {'test_case': 'บริษัn iberry จำกัด มหาชน',
#   'score': 95.01504898071289,
#   'time': 7.343292236328125e-05},
#  {'test_case': 'บริษํท iberry จํากัด มหาชน',
#   'score': 97.38500714302063,
#   'time': 7.796287536621094e-05},
#  {'test_case': 'บ ริ ษั ท iberry จำ กั ด ม ห า ช น',
#   'score': 87.82337307929993,
#   'time': 0.00010800361633300781},
#  {'test_case': 'บริษัท\niberry\tจำกัด   มหาชน',
#   'score': 100.0,
#   'time': 9.083747863769531e-05},
#  {'test_case': 'บริษัท iberry จำกัด มหาชน ประเทศไทย',
#   'score': 93.96494626998901,
#   'time': 8.177757263183594e-05},
#  {'test_case': 'iberry จำกัด มหาชน group',
#   'score': 91.44390821456909,
#   'time': 6.556510925292969e-05},
#  {'test_case': 'iberry จำกัดมหาชน!!',
#   'score': 84.06150937080383,
#   'time': 6.771087646484375e-05},
#  {'test_case': 'บริษัท iberry จำกัด มหาชน 2025',
#   'score': 84.628427028656,
#   'time': 9.34600830078125e-05},
#  {'test_case': 'บริษํท ibery จํากัด มหานชน',
#   'score': 63.55839967727661,
#   'time': 0.00011944770812988281},
#  {'test_case': 'บ ริ ษั ท ibery จำกัดมห า ชน',
#   'score': 70.64052820205688,
#   'time': 9.942054748535156e-05},
#  {'test_case': 'บริษัท ibery มหาชน จำกัด',
#   'score': 77.77727842330933,
#   'time': 8.702278137207031e-05},
#  {'test_case': 'starbucks', 'score': 100.0, 'time': 0.0003407001495361328},
#  {'test_case': 'star bucks',
#   'score': 71.77761793136597,
#   'time': 0.00011515617370605469},
#  {'test_case': 'Starbucks',
#   'score': 78.95498275756836,
#   'time': 7.987022399902344e-05},
#  {'test_case': 'starbuvks',
#   'score': 68.24415326118469,
#   'time': 8.058547973632812e-05},
#  {'test_case': 'strabucks',
#   'score': 88.47757577896118,
#   'time': 9.775161743164062e-05},
#  {'test_case': 'starbicks',
#   'score': 67.64631867408752,
#   'time': 9.584426879882812e-05},
#  {'test_case': 'stqrbucks',
#   'score': 83.05731415748596,
#   'time': 0.00010609626770019531},
#  {'test_case': 'starrbucks',
#   'score': 96.56140804290771,
#   'time': 8.463859558105469e-05},
#  {'test_case': 'starbuck',
#   'score': 97.38836884498596,
#   'time': 6.556510925292969e-05},
#  {'test_case': 'starbuc',
#   'score': 68.98059248924255,
#   'time': 6.341934204101562e-05},
#  {'test_case': 'bucksstar',
#   'score': 57.4163556098938,
#   'time': 6.270408630371094e-05},
#  {'test_case': 'bucks star',
#   'score': 60.406577587127686,
#   'time': 8.487701416015625e-05},
#  {'test_case': 'st4rbucks',
#   'score': 83.36195945739746,
#   'time': 0.00010061264038085938},
#  {'test_case': 'staЯbucks',
#   'score': 80.51441311836243,
#   'time': 7.605552673339844e-05},
#  {'test_case': 'starnuсks',
#   'score': 68.57408881187439,
#   'time': 0.00011086463928222656},
#  {'test_case': 'starbucķs',
#   'score': 70.16046643257141,
#   'time': 0.0001087188720703125},
#  {'test_case': 'stɑrbucks',
#   'score': 92.83682107925415,
#   'time': 9.703636169433594e-05},
#  {'test_case': '  starbucks  ',
#   'score': 100.0,
#   'time': 0.00010561943054199219},
#  {'test_case': 'star   bucks',
#   'score': 71.77761793136597,
#   'time': 0.00012040138244628906},
#  {'test_case': 'star\nbucks',
#   'score': 71.77761793136597,
#   'time': 9.942054748535156e-05},
#  {'test_case': 's t a r b u c k s',
#   'score': 59.21419858932495,
#   'time': 6.866455078125e-05},
#  {'test_case': 'order starbucks now',
#   'score': 79.73656058311462,
#   'time': 6.341934204101562e-05},
#  {'test_case': 'best starbucks coffee',
#   'score': 75.64619183540344,
#   'time': 9.512901306152344e-05},
#  {'test_case': 'st4r buks!!',
#   'score': 53.204941749572754,
#   'time': 0.00011563301086425781},
#  {'test_case': 'order staЯbucķs now',
#   'score': 60.908085107803345,
#   'time': 6.961822509765625e-05}]

# %%
df = pd.DataFrame(model_scores)

# %%
df.to_excel("sentence_transformer_test_cases_results2.xlsx", index=False)
